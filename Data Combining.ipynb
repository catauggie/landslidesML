# %%
import pandas as pd
data = pd.read_excel('data_train_not_nans.xlsx')
data
# Out:
#       Unnamed: 0          event_date   longitude   latitude  \
# 0              1 2009-01-02 02:00:00 -122.663000  45.420000
# 1              3 2009-07-31 00:00:00   81.708000  28.837800
# 2              4 2010-10-16 12:00:00  123.897800  10.333600
# 3              5 2012-02-16 00:00:00  124.966800  10.700400
# 4              6 2012-03-30 00:00:00 -117.266500  48.279700
# ...          ...                 ...         ...        ...
# 9989       11028 2017-04-01 13:34:00  111.679944  -7.853409
# 9990       11029 2017-03-25 17:32:00   75.680611  33.403080
# 9991       11030 2016-12-15 05:00:00   91.772042  26.181606
# 9992       11031 2017-04-29 19:03:00   73.472379  40.886395
# 9993       11032 2017-03-13 14:32:00   78.356505  17.465630
#
#        landslide_category landslide_trigger landslide_size  precipitation-1  \
# 0                mudslide          downpour          small         6.847097
# 1               landslide           monsoon         medium         7.704194
# ...

# %%
reduced_df = pd.read_excel('pca_df.xlsx')
reduced_df
# Out:
#             PC1        PC2        PC3       PC4       PC5       PC6       PC7  \
# 0      2.768696  12.667523   0.411167  2.857535  4.027263 -4.994954  3.366948
# 1     16.082377 -12.845456  -5.202100 -1.907500 -0.821905 -0.870091  0.802201
# 2    -23.173111  -5.290416   0.899408  2.005395 -2.982593 -0.729501  0.320674
# 3    -25.548555  -6.124633   5.522850  2.543240  1.761109  3.466775  4.149016
# 4     14.195970  10.109598   5.356651 -3.538066 -4.099286 -1.796769  5.100535
# ...         ...        ...        ...       ...       ...       ...       ...
# 9989 -19.967703  -5.516079   0.948872  6.533998 -4.228811  3.000546  5.732345
# 9990  24.268872  -8.220326  12.475897 -4.438803 -2.829333 -5.040561  1.971380
# 9991 -15.146782   0.386949  15.532330  9.136227 -2.172533  7.018825 -8.016906
# 9992  23.634228  -1.789336   4.281199 -5.590769 -6.800842 -0.741137  2.937817
# 9993 -10.229515  -1.588400   6.116982 -5.743987 -7.361080 -1.381627 -9.433882
#
# ...

# %%
import pandas as pd
data_ = pd.read_excel('data.xlsx')
data_
# Out:
#                    event_date location_accuracy   landslide_category  \
# 0      08/01/2008 12:00:00 AM           unknown            landslide
# 1      01/02/2009 02:00:00 AM               5km             mudslide
# 2      01/19/2007 12:00:00 AM              10km            landslide
# 3      07/31/2009 12:00:00 AM           unknown            landslide
# 4      10/16/2010 12:00:00 PM               5km            landslide
# ...                       ...               ...                  ...
# 11028  04/01/2017 01:34:00 PM               5km            landslide
# 11029  03/25/2017 05:32:00 PM               5km            landslide
# 11030  12/15/2016 05:00:00 AM               1km            landslide
# 11031  04/29/2017 07:03:00 PM               1km  translational_slide
# 11032  03/13/2017 02:32:00 PM               1km             mudslide
#
#       landslide_trigger landslide_size landslide_setting  fatality_count  \
# ...

# %%
data_['landslide_setting']
# Out:
# array(['mine', 'unknown', 'above_road', 'urban', 'natural_slope', nan,
#        'engineered_slope', 'below_road', 'above_river', 'retaining_wall',
#        'other', 'above_coast', 'bluff', 'burned_area', 'deforested_slope'],
#       dtype=object)

# %%
import pandas as pd
data_0 = pd.read_csv('Global_Landslide_Catalog_Export.csv')
data_0
# Out:
#               source_name                                        source_link  \
# 0                     AGU  https://blogs.agu.org/landslideblog/2008/10/14...
# 1               Oregonian  http://www.oregonlive.com/news/index.ssf/2009/...
# 2                CBS News  https://www.cbsnews.com/news/dozens-missing-af...
# 3                 Reuters  https://in.reuters.com/article/idINIndia-41450...
# 4             The Freeman  http://www.philstar.com/cebu-news/621414/lands...
# ...                   ...                                                ...
# 11028    The Jakarta Post  http://www.thejakartapost.com/news/2017/04/02/...
# 11029     Greater Kashmir  http://www.greaterkashmir.com/news/jammu/lands...
# 11030           NBC Daily  http://www.nbcdaily.com/separate-landslides-ki...
# 11031  AGU Landslide Blog  http://blogs.agu.org/landslideblog/2017/05/02/...
# 11032  The Times of India  https://timesofindia.indiatimes.com/city/hyder...
#
# ...

# %%
ggg = data_0.dropna()
ggg
# Out:
# Empty DataFrame
# Columns: [source_name, source_link, event_id, event_date, event_time, event_title, event_description, location_description, location_accuracy, landslide_category, landslide_trigger, landslide_size, landslide_setting, fatality_count, injury_count, storm_name, photo_link, notes, event_import_source, event_import_id, country_name, country_code, admin_division_name, admin_division_population, gazeteer_closest_point, gazeteer_distance, submitted_date, created_date, last_edited_date, longitude, latitude]
# Index: []
#
# [0 rows x 31 columns]

# %%
data['landslide_setting'] = ggg['landslide_setting']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Users\ivan\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\Users\ivan\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Users\ivan\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'landslide_setting'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data.to_excel('data_train_not_nans.xlsx', index=False)

# %%
data['landslide_trigger'].value_counts()
# Out:
# downpour                   4680
# rain                       2592
# unknown                    1691
# continuous_rain             748
# tropical_cyclone            561
# snowfall_snowmelt           135
# monsoon                     129
# mining                       93
# earthquake                   89
# construction                 82
# flooding                     75
# no_apparent_trigger          44
# freeze_thaw                  41
# other                        26
# dam_embankment_collapse      12
# leaking_pipe                 10
# volcano                       1
# vibration                     1
# Name: landslide_trigger, dtype: int64

# %%
# Объединение DataFrame `data` и `reduced_df`
combined_df = pd.concat([data[['longitude', 'latitude', 'landslide_category', 'landslide_trigger', 'landslide_size']], reduced_df], axis=1)

# %%
combined_df.to_excel('data_to_train.xlsx', index=False)
